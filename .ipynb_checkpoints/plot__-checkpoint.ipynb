# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
a = np.arange(0.0000001, 0.2, 0.0000001)
b = np.sin(1 / a)
plt.plot(a, b, lw=0.1)
# Out:
# C:\Users\FYQ\AppData\Local\Temp\ipykernel_5628\3045130942.py:6: RuntimeWarning: divide by zero encountered in true_divide
#   b = np.sin(1 / a)
# C:\Users\FYQ\AppData\Local\Temp\ipykernel_5628\3045130942.py:6: RuntimeWarning: invalid value encountered in sin
#   b = np.sin(1 / a)
