# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
a = np.arange(0.0000001, 2*np.pi, 0.01)
b = np.sin(a)
plt.plot(a, b, color='yellow', lw=0.2)
